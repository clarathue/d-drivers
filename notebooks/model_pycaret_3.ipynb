# %%
import pandas as pd
import pickle

df = pd.read_csv('../data/data_nlp_A.csv', parse_dates=['last_publish_date', 'date_min'])

# %%
# Initialize PowerTransformer
file_path = "../streamlit_app/pages/power_transformer_ext_impr.pkl"
with open(file_path, "rb") as file:
    loaded_pt = pickle.load(file)

# %%
# transform target and add as new column

target_nt = 'external_impressions'
external_impressions_transformed = loaded_pt.transform(df[[target_nt]])
df['external_impressions_transformed'] = external_impressions_transformed
# Out:
# /Users/brt/.virtualenvs/d-drivers/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but PowerTransformer was fitted without feature names
#   warnings.warn(

# %%
columns_numerical = df.select_dtypes(include=['number']).columns.tolist()
columns_categorical = df.select_dtypes(include=['object', 'category']).columns.tolist()
columns_boolean = df.select_dtypes(include=['bool']).columns.tolist()

# %%
columns_vertex_adopted =[
    'urls_per_days',
    'media_type', # instead of 'Autmedia_type_videohors'
    'word_count',
    'video_player_types', # instead of encoded/transformed 'video_standard_and_widget' and 'video_widget'
    'classification_product',
    # 'video_widget', # commented out, see comment in line 'video_standard_and_widget' and 'video_widget'
    'meta_title_len',
    'author_list',  # instead of 'Authors'
    'google_trend_label',
    'classification_type',
    'meta_desc_len',
    'google_trend_score',
    'abstract_len',
    'h1_len'
    ]

target = 'external_impressions_transformed'

data = df[columns_vertex_adopted + [target]]

# %%
import pycaret.regression as pyreg

# %%
# from pycaret.regression import *

# %%
s = pyreg.setup(data, target=target, transformation=True, session_id=42
          # transform_target=True,
          #  transform_target_method='yeo-johnson', 
          ) #‘yeo-johnson’ in fact lol
# Out:
# <style type="text/css">
# #T_ff272_row10_col1, #T_ff272_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff272">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff272_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ff272_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff272_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff272_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ff272_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff272_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ff272_row1_col1" class="data row1 col1" >external_impressions_transformed</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff272_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ff272_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff272_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ff272_row3_col1" class="data row3 col1" >(6815, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff272_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ff272_row4_col1" class="data row4 col1" >(6815, 40)</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff272_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ff272_row5_col1" class="data row5 col1" >(4770, 40)</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff272_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ff272_row6_col1" class="data row6 col1" >(2045, 40)</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff272_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ff272_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff272_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_ff272_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff272_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_ff272_row9_col1" class="data row9 col1" >14.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ff272_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_ff272_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ff272_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_ff272_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ff272_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_ff272_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ff272_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_ff272_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ff272_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_ff272_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ff272_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_ff272_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ff272_row16_col0" class="data row16 col0" >Transformation</td>
#       <td id="T_ff272_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ff272_row17_col0" class="data row17 col0" >Transformation method</td>
#       <td id="T_ff272_row17_col1" class="data row17 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ff272_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_ff272_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ff272_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_ff272_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ff272_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_ff272_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ff272_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_ff272_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ff272_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_ff272_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ff272_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_ff272_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ff272_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ff272_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_ff272_row24_col1" class="data row24 col1" >d911</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = pyreg.compare_models()
# Out:
# <style type="text/css">
# #T_f457f th {
#   text-align: left;
# }
# #T_f457f_row0_col0, #T_f457f_row0_col5, #T_f457f_row1_col0, #T_f457f_row1_col1, #T_f457f_row1_col2, #T_f457f_row1_col3, #T_f457f_row1_col4, #T_f457f_row1_col6, #T_f457f_row2_col0, #T_f457f_row2_col1, #T_f457f_row2_col2, #T_f457f_row2_col3, #T_f457f_row2_col4, #T_f457f_row2_col5, #T_f457f_row2_col6, #T_f457f_row3_col0, #T_f457f_row3_col1, #T_f457f_row3_col2, #T_f457f_row3_col3, #T_f457f_row3_col4, #T_f457f_row3_col5, #T_f457f_row3_col6, #T_f457f_row4_col0, #T_f457f_row4_col1, #T_f457f_row4_col2, #T_f457f_row4_col3, #T_f457f_row4_col4, #T_f457f_row4_col5, #T_f457f_row4_col6, #T_f457f_row5_col0, #T_f457f_row5_col1, #T_f457f_row5_col2, #T_f457f_row5_col3, #T_f457f_row5_col4, #T_f457f_row5_col5, #T_f457f_row5_col6, #T_f457f_row6_col0, #T_f457f_row6_col1, #T_f457f_row6_col2, #T_f457f_row6_col3, #T_f457f_row6_col4, #T_f457f_row6_col5, #T_f457f_row6_col6, #T_f457f_row7_col0, #T_f457f_row7_col1, #T_f457f_row7_col2, #T_f457f_row7_col3, #T_f457f_row7_col4, #T_f457f_row7_col5, #T_f457f_row7_col6, #T_f457f_row8_col0, #T_f457f_row8_col1, #T_f457f_row8_col2, #T_f457f_row8_col3, #T_f457f_row8_col4, #T_f457f_row8_col5, #T_f457f_row8_col6, #T_f457f_row9_col0, #T_f457f_row9_col1, #T_f457f_row9_col2, #T_f457f_row9_col3, #T_f457f_row9_col4, #T_f457f_row9_col5, #T_f457f_row9_col6, #T_f457f_row10_col0, #T_f457f_row10_col1, #T_f457f_row10_col2, #T_f457f_row10_col3, #T_f457f_row10_col4, #T_f457f_row10_col5, #T_f457f_row10_col6, #T_f457f_row11_col0, #T_f457f_row11_col1, #T_f457f_row11_col2, #T_f457f_row11_col3, #T_f457f_row11_col4, #T_f457f_row11_col5, #T_f457f_row11_col6, #T_f457f_row12_col0, #T_f457f_row12_col1, #T_f457f_row12_col2, #T_f457f_row12_col3, #T_f457f_row12_col4, #T_f457f_row12_col5, #T_f457f_row12_col6, #T_f457f_row13_col0, #T_f457f_row13_col1, #T_f457f_row13_col2, #T_f457f_row13_col3, #T_f457f_row13_col4, #T_f457f_row13_col5, #T_f457f_row13_col6, #T_f457f_row14_col0, #T_f457f_row14_col1, #T_f457f_row14_col2, #T_f457f_row14_col3, #T_f457f_row14_col4, #T_f457f_row14_col5, #T_f457f_row14_col6, #T_f457f_row15_col0, #T_f457f_row15_col1, #T_f457f_row15_col2, #T_f457f_row15_col3, #T_f457f_row15_col4, #T_f457f_row15_col5, #T_f457f_row15_col6, #T_f457f_row16_col0, #T_f457f_row16_col1, #T_f457f_row16_col2, #T_f457f_row16_col3, #T_f457f_row16_col4, #T_f457f_row16_col5, #T_f457f_row16_col6, #T_f457f_row17_col0, #T_f457f_row17_col1, #T_f457f_row17_col2, #T_f457f_row17_col3, #T_f457f_row17_col4, #T_f457f_row17_col5, #T_f457f_row17_col6 {
#   text-align: left;
# }
# #T_f457f_row0_col1, #T_f457f_row0_col2, #T_f457f_row0_col3, #T_f457f_row0_col4, #T_f457f_row0_col6, #T_f457f_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f457f_row0_col7, #T_f457f_row1_col7, #T_f457f_row2_col7, #T_f457f_row3_col7, #T_f457f_row4_col7, #T_f457f_row5_col7, #T_f457f_row7_col7, #T_f457f_row8_col7, #T_f457f_row9_col7, #T_f457f_row10_col7, #T_f457f_row12_col7, #T_f457f_row13_col7, #T_f457f_row14_col7, #T_f457f_row15_col7, #T_f457f_row16_col7, #T_f457f_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f457f_row6_col7, #T_f457f_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f457f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f457f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f457f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f457f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f457f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f457f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f457f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f457f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f457f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f457f_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_f457f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f457f_row0_col1" class="data row0 col1" >0.7248</td>
#       <td id="T_f457f_row0_col2" class="data row0 col2" >0.8590</td>
#       <td id="T_f457f_row0_col3" class="data row0 col3" >0.9260</td>
#       <td id="T_f457f_row0_col4" class="data row0 col4" >0.6020</td>
#       <td id="T_f457f_row0_col5" class="data row0 col5" >0.3466</td>
#       <td id="T_f457f_row0_col6" class="data row0 col6" >2.4765</td>
#       <td id="T_f457f_row0_col7" class="data row0 col7" >0.8190</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_f457f_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f457f_row1_col1" class="data row1 col1" >0.7294</td>
#       <td id="T_f457f_row1_col2" class="data row1 col2" >0.8623</td>
#       <td id="T_f457f_row1_col3" class="data row1 col3" >0.9279</td>
#       <td id="T_f457f_row1_col4" class="data row1 col4" >0.6006</td>
#       <td id="T_f457f_row1_col5" class="data row1 col5" >0.3445</td>
#       <td id="T_f457f_row1_col6" class="data row1 col6" >2.4976</td>
#       <td id="T_f457f_row1_col7" class="data row1 col7" >0.1760</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_f457f_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_f457f_row2_col1" class="data row2 col1" >0.7373</td>
#       <td id="T_f457f_row2_col2" class="data row2 col2" >0.8920</td>
#       <td id="T_f457f_row2_col3" class="data row2 col3" >0.9437</td>
#       <td id="T_f457f_row2_col4" class="data row2 col4" >0.5869</td>
#       <td id="T_f457f_row2_col5" class="data row2 col5" >0.3521</td>
#       <td id="T_f457f_row2_col6" class="data row2 col6" >2.5486</td>
#       <td id="T_f457f_row2_col7" class="data row2 col7" >0.4470</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_f457f_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_f457f_row3_col1" class="data row3 col1" >0.7452</td>
#       <td id="T_f457f_row3_col2" class="data row3 col2" >0.9152</td>
#       <td id="T_f457f_row3_col3" class="data row3 col3" >0.9562</td>
#       <td id="T_f457f_row3_col4" class="data row3 col4" >0.5758</td>
#       <td id="T_f457f_row3_col5" class="data row3 col5" >0.3592</td>
#       <td id="T_f457f_row3_col6" class="data row3 col6" >2.5323</td>
#       <td id="T_f457f_row3_col7" class="data row3 col7" >0.3390</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_f457f_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_f457f_row4_col1" class="data row4 col1" >0.7628</td>
#       <td id="T_f457f_row4_col2" class="data row4 col2" >0.9661</td>
#       <td id="T_f457f_row4_col3" class="data row4 col3" >0.9822</td>
#       <td id="T_f457f_row4_col4" class="data row4 col4" >0.5521</td>
#       <td id="T_f457f_row4_col5" class="data row4 col5" >0.3655</td>
#       <td id="T_f457f_row4_col6" class="data row4 col6" >2.6028</td>
#       <td id="T_f457f_row4_col7" class="data row4 col7" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_f457f_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_f457f_row5_col1" class="data row5 col1" >0.8355</td>
#       <td id="T_f457f_row5_col2" class="data row5 col2" >1.0835</td>
#       <td id="T_f457f_row5_col3" class="data row5 col3" >1.0405</td>
#       <td id="T_f457f_row5_col4" class="data row5 col4" >0.4982</td>
#       <td id="T_f457f_row5_col5" class="data row5 col5" >0.3750</td>
#       <td id="T_f457f_row5_col6" class="data row5 col6" >3.0807</td>
#       <td id="T_f457f_row5_col7" class="data row5 col7" >0.2060</td>
#     </tr>
#     <tr>
#       <th id="T_f457f_l

# %%
pyreg.plot_model(best, plot = 'residuals')

# %%
pyreg.plot_model(best, plot='error')

# %%
pyreg.plot_model(best, plot = 'feature')

# %%
pyreg.save_experiment('../models/bl_experiment_ext_imp_trans.pkl')

# %%
lightgbm = pyreg.create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_653c1_row10_col0, #T_653c1_row10_col1, #T_653c1_row10_col2, #T_653c1_row10_col3, #T_653c1_row10_col4, #T_653c1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_653c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_653c1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_653c1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_653c1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_653c1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_653c1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_653c1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_653c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_653c1_row0_col0" class="data row0 col0" >0.7353</td>
#       <td id="T_653c1_row0_col1" class="data row0 col1" >0.8839</td>
#       <td id="T_653c1_row0_col2" class="data row0 col2" >0.9402</td>
#       <td id="T_653c1_row0_col3" class="data row0 col3" >0.5860</td>
#       <td id="T_653c1_row0_col4" class="data row0 col4" >0.3568</td>
#       <td id="T_653c1_row0_col5" class="data row0 col5" >1.7267</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_653c1_row1_col0" class="data row1 col0" >0.7105</td>
#       <td id="T_653c1_row1_col1" class="data row1 col1" >0.8458</td>
#       <td id="T_653c1_row1_col2" class="data row1 col2" >0.9197</td>
#       <td id="T_653c1_row1_col3" class="data row1 col3" >0.6000</td>
#       <td id="T_653c1_row1_col4" class="data row1 col4" >0.3429</td>
#       <td id="T_653c1_row1_col5" class="data row1 col5" >2.4549</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_653c1_row2_col0" class="data row2 col0" >0.7141</td>
#       <td id="T_653c1_row2_col1" class="data row2 col1" >0.8394</td>
#       <td id="T_653c1_row2_col2" class="data row2 col2" >0.9162</td>
#       <td id="T_653c1_row2_col3" class="data row2 col3" >0.5877</td>
#       <td id="T_653c1_row2_col4" class="data row2 col4" >0.3511</td>
#       <td id="T_653c1_row2_col5" class="data row2 col5" >3.3384</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_653c1_row3_col0" class="data row3 col0" >0.7451</td>
#       <td id="T_653c1_row3_col1" class="data row3 col1" >0.9172</td>
#       <td id="T_653c1_row3_col2" class="data row3 col2" >0.9577</td>
#       <td id="T_653c1_row3_col3" class="data row3 col3" >0.5937</td>
#       <td id="T_653c1_row3_col4" class="data row3 col4" >0.3608</td>
#       <td id="T_653c1_row3_col5" class="data row3 col5" >1.8885</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_653c1_row4_col0" class="data row4 col0" >0.7642</td>
#       <td id="T_653c1_row4_col1" class="data row4 col1" >0.9540</td>
#       <td id="T_653c1_row4_col2" class="data row4 col2" >0.9767</td>
#       <td id="T_653c1_row4_col3" class="data row4 col3" >0.6228</td>
#       <td id="T_653c1_row4_col4" class="data row4 col4" >0.3481</td>
#       <td id="T_653c1_row4_col5" class="data row4 col5" >2.1247</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_653c1_row5_col0" class="data row5 col0" >0.6844</td>
#       <td id="T_653c1_row5_col1" class="data row5 col1" >0.7610</td>
#       <td id="T_653c1_row5_col2" class="data row5 col2" >0.8724</td>
#       <td id="T_653c1_row5_col3" class="data row5 col3" >0.6569</td>
#       <td id="T_653c1_row5_col4" class="data row5 col4" >0.3190</td>
#       <td id="T_653c1_row5_col5" class="data row5 col5" >1.7202</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_653c1_row6_col0" class="data row6 col0" >0.6910</td>
#       <td id="T_653c1_row6_col1" class="data row6 col1" >0.7725</td>
#       <td id="T_653c1_row6_col2" class="data row6 col2" >0.8789</td>
#       <td id="T_653c1_row6_col3" class="data row6 col3" >0.6153</td>
#       <td id="T_653c1_row6_col4" class="data row6 col4" >0.3336</td>
#       <td id="T_653c1_row6_col5" class="data row6 col5" >1.4630</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_653c1_row7_col0" class="data row7 col0" >0.7746</td>
#       <td id="T_653c1_row7_col1" class="data row7 col1" >0.9832</td>
#       <td id="T_653c1_row7_col2" class="data row7 col2" >0.9916</td>
#       <td id="T_653c1_row7_col3" class="data row7 col3" >0.5254</td>
#       <td id="T_653c1_row7_col4" class="data row7 col4" >0.3763</td>
#       <td id="T_653c1_row7_col5" class="data row7 col5" >4.8966</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_653c1_row8_col0" class="data row8 col0" >0.7146</td>
#       <td id="T_653c1_row8_col1" class="data row8 col1" >0.8350</td>
#       <td id="T_653c1_row8_col2" class="data row8 col2" >0.9138</td>
#       <td id="T_653c1_row8_col3" class="data row8 col3" >0.5963</td>
#       <td id="T_653c1_row8_col4" class="data row8 col4" >0.3274</td>
#       <td id="T_653c1_row8_col5" class="data row8 col5" >3.5533</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_653c1_row9_col0" class="data row9 col0" >0.7140</td>
#       <td id="T_653c1_row9_col1" class="data row9 col1" >0.7976</td>
#       <td id="T_653c1_row9_col2" class="data row9 col2" >0.8931</td>
#       <td id="T_653c1_row9_col3" class="data row9 col3" >0.6363</td>
#       <td id="T_653c1_row9_col4" class="data row9 col4" >0.3496</td>
#       <td id="T_653c1_row9_col5" class="data row9 col5" >1.5983</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_653c1_row10_col0" class="data row10 col0" >0.7248</td>
#       <td id="T_653c1_row10_col1" class="data row10 col1" >0.8590</td>
#       <td id="T_653c1_row10_col2" class="data row10 col2" >0.9260</td>
#       <td id="T_653c1_row10_col3" class="data row10 col3" >0.6020</td>
#       <td id="T_653c1_row10_col4" class="data row10 col4" >0.3466</td>
#       <td id="T_653c1_row10_col5" class="data row10 col5" >2.4765</td>
#     </tr>
#     <tr>
#       <th id="T_653c1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_653c1_row11_col0" class="data row11 col0" >0.0281</td>
#       <td id="T_653c1_row11_col1" class="data row11 col1" >0.0710</td>
#       <td id="T_653c1_row11_col2" class="data row11 col2" >0.0381</td>
#       <td id="T_653c1_row11_col3" class="data row11 col3" >0.0335</td>
#       <td id="T_653c1_row11_col4" class="data row11 col4" >0.0159</td>
#       <td id="T_653c1_row11_col5" class="data row11 col5" >1.0565</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # X. Tune Hyperparameters

# %%
tuned_lightgbm = pyreg.tune_model(lightgbm, n_iter=50, optimize = 'R2')
# Out:
# <style type="text/css">
# #T_2d64f_row10_col0, #T_2d64f_row10_col1, #T_2d64f_row10_col2, #T_2d64f_row10_col3, #T_2d64f_row10_col4, #T_2d64f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2d64f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d64f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2d64f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2d64f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2d64f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2d64f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2d64f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d64f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d64f_row0_col0" class="data row0 col0" >0.7324</td>
#       <td id="T_2d64f_row0_col1" class="data row0 col1" >0.8884</td>
#       <td id="T_2d64f_row0_col2" class="data row0 col2" >0.9425</td>
#       <td id="T_2d64f_row0_col3" class="data row0 col3" >0.5839</td>
#       <td id="T_2d64f_row0_col4" class="data row0 col4" >0.3582</td>
#       <td id="T_2d64f_row0_col5" class="data row0 col5" >1.6662</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d64f_row1_col0" class="data row1 col0" >0.6960</td>
#       <td id="T_2d64f_row1_col1" class="data row1 col1" >0.7970</td>
#       <td id="T_2d64f_row1_col2" class="data row1 col2" >0.8927</td>
#       <td id="T_2d64f_row1_col3" class="data row1 col3" >0.6231</td>
#       <td id="T_2d64f_row1_col4" class="data row1 col4" >0.3367</td>
#       <td id="T_2d64f_row1_col5" class="data row1 col5" >2.2702</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d64f_row2_col0" class="data row2 col0" >0.7304</td>
#       <td id="T_2d64f_row2_col1" class="data row2 col1" >0.8593</td>
#       <td id="T_2d64f_row2_col2" class="data row2 col2" >0.9270</td>
#       <td id="T_2d64f_row2_col3" class="data row2 col3" >0.5779</td>
#       <td id="T_2d64f_row2_col4" class="data row2 col4" >0.3583</td>
#       <td id="T_2d64f_row2_col5" class="data row2 col5" >3.4595</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d64f_row3_col0" class="data row3 col0" >0.7238</td>
#       <td id="T_2d64f_row3_col1" class="data row3 col1" >0.8634</td>
#       <td id="T_2d64f_row3_col2" class="data row3 col2" >0.9292</td>
#       <td id="T_2d64f_row3_col3" class="data row3 col3" >0.6175</td>
#       <td id="T_2d64f_row3_col4" class="data row3 col4" >0.3511</td>
#       <td id="T_2d64f_row3_col5" class="data row3 col5" >1.7086</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d64f_row4_col0" class="data row4 col0" >0.7569</td>
#       <td id="T_2d64f_row4_col1" class="data row4 col1" >0.9311</td>
#       <td id="T_2d64f_row4_col2" class="data row4 col2" >0.9649</td>
#       <td id="T_2d64f_row4_col3" class="data row4 col3" >0.6318</td>
#       <td id="T_2d64f_row4_col4" class="data row4 col4" >0.3524</td>
#       <td id="T_2d64f_row4_col5" class="data row4 col5" >2.3968</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d64f_row5_col0" class="data row5 col0" >0.6955</td>
#       <td id="T_2d64f_row5_col1" class="data row5 col1" >0.7490</td>
#       <td id="T_2d64f_row5_col2" class="data row5 col2" >0.8654</td>
#       <td id="T_2d64f_row5_col3" class="data row5 col3" >0.6623</td>
#       <td id="T_2d64f_row5_col4" class="data row5 col4" >0.3155</td>
#       <td id="T_2d64f_row5_col5" class="data row5 col5" >1.6326</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d64f_row6_col0" class="data row6 col0" >0.6936</td>
#       <td id="T_2d64f_row6_col1" class="data row6 col1" >0.7838</td>
#       <td id="T_2d64f_row6_col2" class="data row6 col2" >0.8853</td>
#       <td id="T_2d64f_row6_col3" class="data row6 col3" >0.6097</td>
#       <td id="T_2d64f_row6_col4" class="data row6 col4" >0.3403</td>
#       <td id="T_2d64f_row6_col5" class="data row6 col5" >1.4547</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d64f_row7_col0" class="data row7 col0" >0.7670</td>
#       <td id="T_2d64f_row7_col1" class="data row7 col1" >0.9818</td>
#       <td id="T_2d64f_row7_col2" class="data row7 col2" >0.9909</td>
#       <td id="T_2d64f_row7_col3" class="data row7 col3" >0.5261</td>
#       <td id="T_2d64f_row7_col4" class="data row7 col4" >0.3772</td>
#       <td id="T_2d64f_row7_col5" class="data row7 col5" >4.6875</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d64f_row8_col0" class="data row8 col0" >0.7107</td>
#       <td id="T_2d64f_row8_col1" class="data row8 col1" >0.8179</td>
#       <td id="T_2d64f_row8_col2" class="data row8 col2" >0.9044</td>
#       <td id="T_2d64f_row8_col3" class="data row8 col3" >0.6045</td>
#       <td id="T_2d64f_row8_col4" class="data row8 col4" >0.3276</td>
#       <td id="T_2d64f_row8_col5" class="data row8 col5" >3.7469</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d64f_row9_col0" class="data row9 col0" >0.6943</td>
#       <td id="T_2d64f_row9_col1" class="data row9 col1" >0.7786</td>
#       <td id="T_2d64f_row9_col2" class="data row9 col2" >0.8824</td>
#       <td id="T_2d64f_row9_col3" class="data row9 col3" >0.6449</td>
#       <td id="T_2d64f_row9_col4" class="data row9 col4" >0.3421</td>
#       <td id="T_2d64f_row9_col5" class="data row9 col5" >1.6097</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2d64f_row10_col0" class="data row10 col0" >0.7201</td>
#       <td id="T_2d64f_row10_col1" class="data row10 col1" >0.8450</td>
#       <td id="T_2d64f_row10_col2" class="data row10 col2" >0.9185</td>
#       <td id="T_2d64f_row10_col3" class="data row10 col3" >0.6082</td>
#       <td id="T_2d64f_row10_col4" class="data row10 col4" >0.3460</td>
#       <td id="T_2d64f_row10_col5" class="data row10 col5" >2.4633</td>
#     </tr>
#     <tr>
#       <th id="T_2d64f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2d64f_row11_col0" class="data row11 col0" >0.0254</td>
#       <td id="T_2d64f_row11_col1" class="data row11 col1" >0.0700</td>
#       <td id="T_2d64f_row11_col2" class="data row11 col2" >0.0377</td>
#       <td id="T_2d64f_row11_col3" class="data row11 col3" >0.0366</td>
#       <td id="T_2d64f_row11_col4" class="data row11 col4" >0.0166</td>
#       <td id="T_2d64f_row11_col5" class="data row11 col5" >1.0616</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 50 candidates, totalling 500 fits

# %%
tuned_lightgbm
# Out:
# LGBMRegressor(bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.8,
#               learning_rate=0.05, min_child_samples=31, min_split_gain=0.3,
#               n_estimators=130, n_jobs=-1, num_leaves=80, random_state=42,
#               reg_alpha=2, reg_lambda=0.4)

# %% [markdown]
# # X. Save and Load model

# %%
pyreg.save_model(model=tuned_lightgbm, model_name='../models/lightgbm_tuned_ext_imp_pt')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['urls_per_days', 'word_count',
#                                               'meta_title_len', 'meta_desc_len',
#                                               'google_trend_score',
#                                               'abstract_len', 'h1_len'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['media_type', 'video_player_types',
#                                               'classification_product',
#                                               'author_...
#                                                                handle_missing='return_nan'))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
#                  ('trained_model',
#                   LGBMRegressor(bagging_fraction=0.8, bagging_freq=0,
#                                 feature_fraction=0.8, learning_rate=0.05,
#                                 min_child_samples=31, min_split_gain=0.3,
#                                 n_estimators=130, n_jobs=-1, num_leaves=80,
#                                 random_state=42, reg_alpha=2, reg_lambda=0.4))]),
#  '../models/lightgbm_tuned_ext_imp_pt.pkl')

# %%
model_loaded = pyreg.load_model('../models/lightgbm_tuned_ext_imp_pt')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# display pipeline

from sklearn import set_config
set_config(display='diagram')
model_loaded[0]
# Out:
# TransformerWrapper(include=['urls_per_days', 'word_count', 'meta_title_len',
#                             'meta_desc_len', 'google_trend_score',
#                             'abstract_len', 'h1_len'],
#                    transformer=SimpleImputer())

# %% [markdown]
# # 2. predict

# %%
instance_dict = {
    "word_count": 390,
    "classification_product": 'Solaranlagen',
    "classification_type": 'Kaufberatung',
    "urls_per_days": 0.1,
    "meta_title_len": 75,
    "meta_desc_len": 145,
    "h1_len": 66,
    "abstract_len": 250,
    "google_trend_label": 'elektroauto',
    "google_trend_score": 33,
    "video_player_types": '2 - Standard and Widget',
    "media_type": 'video',
    "author_list": 'Lisa Brack',
}

# %%
x = pd.DataFrame([instance_dict])

y_trans = model_loaded.predict(x)
y_trans
# Out:
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# array([3.24183743])

# %%
# back transform

y = loaded_pt.inverse_transform(y_trans.reshape(-1, 1))
y[0][0]
# Out:
# 1202124.2238394711

# %%
# alternative prediction with original model instance

predict_new = pyreg.predict_model(tuned_lightgbm, data=x)
predicted_value = predict_new['prediction_label'][0]
display(predicted_value)
display(predict_new.head())
# Out:
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# 3.2418374349356913
#    word_count classification_product classification_type  urls_per_days
# 0         390           Solaranlagen        Kaufberatung            0.1  \
#
#    meta_title_len  meta_desc_len  h1_len  abstract_len google_trend_label
# 0              75            145      66           250        elektroauto  \
#
#    google_trend_score       video_player_types media_type author_list
# 0                  33  2 - Standard and Widget      video  Lisa Brack  \
#
#    prediction_label
# 0          3.241837
